# %%
#display board
#player input
#input on board
#check if game is won,lost or tied
#ask player for round 2

# %%
board=["0","1","2","3","4","5","6","7","8"]

# %%
#player input
def input_player():
    board=["1","2","3","4","5","6","7","8","9"]
    '''print("_"+board[0]+"_|_"+board[1]+"_|_"+board[2]+"_")
    print("_"+board[3]+"_|_"+board[4]+"_|_"+board[5]+"_")
    print("_"+board[6]+"_|_"+board[7]+"_|_"+board[8]+"_")'''
    for i in range(len(board)):
        print("_"+board[0]+"_|_"+board[1]+"_|_"+board[2]+"_")
        print("_"+board[3]+"_|_"+board[4]+"_|_"+board[5]+"_")
        print("_"+board[6]+"_|_"+board[7]+"_|_"+board[8]+"_")
        
        player1=input("Enter the position PLAYER 1: ")
        index=board.index(player1)
        board[index]=input("Enter O: ")
        
        player2=input("Enter the position PLAYER 2: ")
        index1=board.index(player2)
        board[index1]=input("Enter X: ")
        
    
        if (board[0]==board[1]==board[2]=="X" ):
            print("Player 2 Wins")
            break
            
        elif (board[3]==board[4]==board[5]=="X" ):
            print("player 2 Wins")
            break
            
        elif (board[6]==board[7]==board[8]=="X" ):
            print("player 2 Wins")
            break
            
        elif (board[0]==board[4]==board[8]=="X" ): 
            print("Player 2 Wins")
            break
            
        elif (board[2]==board[4]==board[6]=="X"):
            print("Player 2 Wins")
            break
            
        elif (board[0]==board[1]==board[2]=="O"):
            print("Player 1 wins")
            break
            
        elif (board[3]==board[4]==board[5]=="O" ):
            print("Player 1 wins")
            break
            
        elif (board[0]==board[4]==board[8]=="O" ):
            print("Player 1 wins")
            break
            
        elif (board[6]==board[7]==board[8]=="O" ):
            print("Player 1 Wins")
            break
            
        elif (board[2]==board[4]==board[6]=="O" ):
            print("Player 1 Wins")
            break

input_player()
# Out:
# _1_|_2_|_3_
# _4_|_5_|_6_
# _7_|_8_|_9_
# Enter the position PLAYER 1: 1
# Enter O: O
# Enter the position PLAYER 2: 5
# Enter X: X
# _O_|_2_|_3_
# _4_|_X_|_6_
# _7_|_8_|_9_
# Enter the position PLAYER 1: 2
# Enter O: O
# Enter the position PLAYER 2: 8
# Enter X: X
# _O_|_O_|_3_
# _4_|_X_|_6_
# _7_|_X_|_9_
# Enter the position PLAYER 1: 3
# Enter O: O
# Enter the position PLAYER 2: 4
# Enter X: X
# Player 1 wins

# %%
#player input
def input_player():
    board=["1","2","3","4","5","6","7","8","9"]
    print("_"+board[0]+"_|_"+board[1]+"_|_"+board[2]+"_")
    print("_"+board[3]+"_|_"+board[4]+"_|_"+board[5]+"_")
    print("_"+board[6]+"_|_"+board[7]+"_|_"+board[8]+"_")
    for i in range(len(board)):
        player1=input("Enter the position PLAYER 1: ")
        index=board.index(player1)
        board[index]=input("Enter O: ")
        
        player2=input("Enter the position PLAYER 2: ")
        index1=board.index(player2)
        board[index1]=input("Enter X: ")
        
        print("_"+board[0]+"_|_"+board[1]+"_|_"+board[2]+"_")
        print("_"+board[3]+"_|_"+board[4]+"_|_"+board[5]+"_")
        print("_"+board[6]+"_|_"+board[7]+"_|_"+board[8]+"_")
    
        if (board[0]==board[1]==board[2]=="X" ):
            print("Player 2 Wins")
            break
            
        elif (board[3]==board[4]==board[5]=="X" ):
            print("player 2 Wins")
            break
            
        elif (board[6]==board[7]==board[8]=="X" ):
            print("player 2 Wins")
            break
            
        elif (board[0]==board[4]==board[8]=="X" ): 
            print("Player 2 Wins")
            break
            
        elif (board[2]==board[4]==board[6]=="X"):
            print("Player 2 Wins")
            break
            
        elif (board[0]==board[1]==board[2]=="O"):
            print("Player 1 wins")
            break
            
        elif (board[3]==board[4]==board[5]=="O" ):
            print("Player 1 wins")
            break
            
        elif (board[0]==board[4]==board[8]=="O" ):
            print("Player 1 wins")
            break
            
        elif (board[6]==board[7]==board[8]=="O" ):
            print("Player 1 Wins")
            break
            
        elif (board[2]==board[4]==board[6]=="O" ):
            print("Player 1 Wins")
            break

input_player()
# Out:
# _1_|_2_|_3_
# _4_|_5_|_6_
# _7_|_8_|_9_
# Enter the position PLAYER 1: 1
# Enter O: O
# Enter the position PLAYER 2: 5
# Enter X: X
# _O_|_2_|_3_
# _4_|_X_|_6_
# _7_|_8_|_9_
# Enter the position PLAYER 1: 2
# Enter O: O
# Enter the position PLAYER 2: 6
# Enter X: X
# _O_|_O_|_3_
# _4_|_X_|_X_
# _7_|_8_|_9_
# Enter the position PLAYER 1: 3
# Enter O: O
# Enter the position PLAYER 2: 8
# Enter X: X
# _O_|_O_|_O_
# _4_|_X_|_X_
# _7_|_X_|_9_
# Player 1 wins
